# %% [markdown]
# ### Import CSV

# %%
import pandas as pd


df = pd.read_csv("C:/Users/Marwan Albanna/AppData/Roaming/Python/Python39/superstore.csv",encoding = 'unicode_escape')

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Postal Code         Sales       Quantity     Discount       Profit
# count   9985.000000   9994.000000    9991.000000  9994.000000  9994.000000
# mean   55201.417927    229.858001      55.169953     0.156203    28.656896
# std    32067.257228    623.245101    5003.265115     0.206452   234.260108
# min     1040.000000      0.444000       1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000       2.000000     0.000000     1.728750
# 50%    56560.000000     54.490000       3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000       5.000000     0.200000    29.364000
# max    99301.000000  22638.480000  500000.000000     0.800000  8399.976000

# %%
df.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      9
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         3
# Discount         0
# Profit           0
# dtype: int64

# %%
df.infoa
# Out:
# <bound method DataFrame.info of             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688  06/12/2016   6/16/2016    second class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
# ...

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         3
# Discount         0
# Profit           0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
 264, 321, 399

# %%
df[df.isnull().any(axis=1)]
# Out:
#            Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 264  CA-2016-125318  06/06/2016   6/13/2016  Standard Class    RC-19825
# 321  CA-2014-164973  11/04/2014  11/09/2014  Standard Class    NM-18445
# 399  CA-2016-108987  09/08/2016  09/10/2016    Second Class    AG-10675
#
#     Customer Name      Segment        Country           City     State  \
# 264   Roy Collins     Consumer  United States        Chicago  Illinois
# 321  Nathan Mautz  Home Office  United States  New York City  New York
# 399   Anna Gayman     Consumer  United States        Houston     Texas
#
#      Postal Code    Region       Product ID         Category Sub-Category  \
# 264      60610.0  Illinois  TEC-PH-10001433       Technology       Phones
# 321      10024.0  New York  OFF-ST-10002974  Office Supplies      Storage
# 399      77036.0     Texas  FUR-BO-10004834        Furniture    Bookcases
#
#                                           Product Name      Sales  Quantity  \
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### Value counts all attributes

# %%
df['Order ID'].value_counts()
# Out:
# CA-2017-100111    14
# CA-2017-157987    12
# CA-2016-165330    11
# US-2016-108504    11
# CA-2015-131338    10
#                   ..
# CA-2016-144554     1
# US-2016-115952     1
# CA-2015-113040     1
# US-2014-169390     1
# CA-2017-111647     1
# Name: Order ID, Length: 5009, dtype: int64

# %%
df['Order Date'].value_counts()
# Out:
# 09/05/2016    38
# 09/02/2017    36
# 11/10/2016    35
# 12/02/2017    34
# 12/01/2017    34
#               ..
# 1/28/2014      1
# 12/23/2015     1
# 1/24/2015      1
# 01/09/2017     1
# 03/07/2016     1
# Name: Order Date, Length: 1237, dtype: int64

# %%
df['Ship Date'].value_counts()
# Out:
# 12/16/2015    35
# 9/26/2017     34
# 11/21/2017    32
# 12/06/2017    32
# 09/06/2017    30
#               ..
# 08/10/2014     1
# 2/25/2014      1
# 01/08/2017     1
# 4/28/2017      1
# 3/29/2014      1
# Name: Ship Date, Length: 1334, dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class     5965
# Second Class       1941
# First Class        1533
# Same Day            543
# first class           5
# second class          4
# standard class        1
# standard Classs       1
# standard Class        1
# Name: Ship Mode, dtype: int64

# %%
df['Customer ID'].value_counts()
# Out:
# WB-21850    37
# JL-15835    34
# PP-18955    34
# MA-17560    34
# EH-13765    32
#             ..
# sp-20650     1
# jh-15985     1
# LD-16855     1
# rm-19675     1
# RE-19405     1
# Name: Customer ID, Length: 798, dtype: int64

# %%
df['Customer Name'].value_counts()
# Out:
# William Brown        37
# Matt Abelman         34
# John Lee             34
# Paul Prost           34
# Jonathan Doherty     32
#                      ..
# Lela Donovan          1
# Carl Jackson          1
# Anthony O'Donnell     1
# Jocasta Rupert        1
# Ricardo Emerson       1
# Name: Customer Name, Length: 793, dtype: int64

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5186
# Corporate      3016
# Home Office    1781
# consumer          5
# corporate         4
# home office       2
# Name: Segment, dtype: int64

# %%
df['City'].value_counts()
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Missouri City      1
# Ormond Beach       1
# Jupiter            1
# Elyria             1
# Lake Elsinore      1
# Name: City, Length: 531, dtype: int64

# %%
df['State'].value_counts()
# Out:
# California              1998
# New York                1124
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  382
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Mississippi               53
# Utah                      53
# ...

# %%
df['Region'].value_counts()
# Out:
# West       3199
# East       2846
# Central    2319
# South      1619
# W             4
# C             4
# E             2
# S             1
# Name: Region, dtype: int64

# %%
df['Product ID'].value_counts()
# Out:
# OFF-PA-10001970    19
# TEC-AC-10003832    18
# FUR-FU-10004270    16
# FUR-CH-10001146    15
# FUR-CH-10002647    15
#                    ..
# TEC-MA-10002927     1
# FUR-BO-10001567     1
# TEC-PH-10004830     1
# OFF-EN-10001535     1
# OFF-PA-10001281     1
# Name: Product ID, Length: 1862, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
df['Product Name'].value_counts()
# Out:
# Staple envelope                                                              48
# Easy-staple paper                                                            46
# Staples                                                                      46
# Avery Non-Stick Binders                                                      20
# Staples in misc. colors                                                      19
#                                                                              ..
# Penpower WorldCard Pro Card Scanner                                           1
# Konica Minolta magicolor 1690MF Multifunction Printer                         1
# RCA H5401RE1 DECT 6.0 4-Line Cordless Handset With Caller ID/Call Waiting     1
# Xerox 1969                                                                    1
# Xerox 1938                                                                    1
# Name: Product Name, Length: 1850, dtype: int64

# %%
df['Sales'].value_counts()
# Out:
# 12.960     56
# 19.440     39
# 15.552     39
# 25.920     36
# 10.368     36
#            ..
# 376.866     1
# 572.800     1
# 3.928       1
# 12.032      1
# 629.640     1
# Name: Sales, Length: 5825, dtype: int64

# %%
df['Quantity'].value_counts()
# Out:
# 3.0         2408
# 2.0         2400
# 5.0         1230
# 4.0         1189
# 1.0          897
# 7.0          606
# 6.0          572
# 9.0          258
# 8.0          257
# 10.0          57
# 11.0          34
# 14.0          29
# 13.0          27
# 12.0          23
# 500000.0       1
# 10000.0        1
# 1000.0         1
# 2347.0         1
# Name: Quantity, dtype: int64

# %%
df['Discount'].value_counts()
# Out:
# 0.00    4798
# 0.20    3657
# 0.70     418
# 0.80     300
# 0.30     227
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64

# %%
df['Profit'].value_counts()
# Out:
#  0.0000      65
#  6.2208      43
#  9.3312      38
#  5.4432      32
#  3.6288      32
#              ..
# -3.5622       1
# -7.4800       1
#  626.1850     1
# -12.8392      1
#  6.1704       1
# Name: Profit, Length: 7287, dtype: int64

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688  06/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %% [markdown]
# ### Rename

# %%
Segment, state , region , ship mode

# %%
ci = df[df.duplicated('Customer ID')]

# %%
ci
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 6     CA-2014-115812  06/09/2014   6/14/2014  Standard Class    BH-11710
# 7     CA-2014-115812  06/09/2014   6/14/2014  Standard Class    BH-11710
# 8     CA-2014-115812  06/09/2014   6/14/2014  Standard Class    BH-11710
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name   Segment        Country             City       State  \
# ...

# %%
cs = df[df.duplicated('Customer Name')]

# %%
cs
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 6     CA-2014-115812  06/09/2014   6/14/2014  Standard Class    BH-11710
# 7     CA-2014-115812  06/09/2014   6/14/2014  Standard Class    BH-11710
# 8     CA-2014-115812  06/09/2014   6/14/2014  Standard Class    BH-11710
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name   Segment        Country             City       State  \
# ...

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df['Ship Mode'] = df['Ship Mode'].replace({'second class': 'Second Class','standard Class': 'Standard Class','standard class': 'Standard Class' , 'standard Classs' : 'Standard Class','first class' :'First Class',}) #states

# %%
df['Region'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df['Region'] = df['State'].replace({'S': 'South','E': 'East' , 'C' : 'Central', 'W' : 'West'}) #states

# %%
df['State'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df['State'] = df['State'].replace({'NY': 'New York','FL': 'Florida' , 'CL' : 'California'}) #states

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688  06/12/2016   6/16/2016    second class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df['State'].va

# %%
df['Segment'] = df['Segment'].replace({'home office': 'Home Office','corporate': 'Corporate' , 'consumer' : 'Consumer'}) #renaming Genders

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688  06/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df.loc[df]

# %%
df.loc[181, 'Postal Code'] = 62521.0

# %% [markdown]
# # missing ZIP -  Indexes renamed below

# %% [markdown]
# 701, 654, 609, 561, 483, 411, 399, 332 , 321, 264, 257, 181

# %%
df.loc[(df['Product Name'] == 'Newell 312')
# Out:
#   File "<ipython-input-195-7350af8bea4c>", line 1
#     df.loc[(df['Product Name'] == 'Newell 312')
#                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.loc[181, 'Postal Code'] = 62521.0

# %%
df['Postal Code'].value_counts()
# Out:
# 10035.0    264
# 10024.0    229
# 10009.0    229
# 94122.0    204
# 10011.0    193
#           ...
# 34741.0      1
# 11757.0      1
# 90604.0      1
# 92530.0      1
# 8401.0       1
# Name: Postal Code, Length: 631, dtype: int64

# %%
 264, 321, 399

# %%
df[(df['Sub-Category'] == 'Phones')
# Out:
#   File "<ipython-input-216-97aff4ad93cb>", line 1
#     df[(df['Sub-Category'] == 'Phones')
#                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
Cisco Small Business SPA 502G VoIP phone

# %%
Trav-L-File Heavy-Duty Shuttle II, Black

# %%
Riverside Palais Royal Lawyers Bookcase, Royal..  --399

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df['Region'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df[df['Product Name'] == 'Trav-L-File Heavy-Duty Shuttle II, Black']
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 127   US-2017-107272  11/05/2017  11/12/2017  Standard Class    TS-21610
# 321   CA-2014-164973  11/04/2014  11/09/2014  Standard Class    NM-18445
# 578   CA-2017-118640   7/20/2017   7/26/2017  Standard Class    CS-11950
# 1443  CA-2015-166135  10/01/2015  10/06/2015  Standard Class    SC-20440
# 3619  CA-2017-141929  09/04/2017  09/08/2017  Standard Class    RA-19285
# 4708  CA-2017-138149   6/29/2017   6/30/2017     First Class    WB-21850
# 9090  US-2017-148831  10/13/2017  10/15/2017     First Class    AH-10210
#
#        Customer Name      Segment        Country           City       State  \
# 127     Troy Staebel     Consumer  United States        Phoenix     Arizona
# 321     Nathan Mautz  Home Office  United States  New York City    New York
# 578   Carlos Soltero     Consumer  United States        Chicago    Illinois
# 1443    Shaun Chance    Corporate  United States         Aurora    Colorado
# ...

# %%
df[df['Product Name'] == 'Cisco Small Business SPA 502G VoIP phone']
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 264   CA-2016-125318  06/06/2016   6/13/2016  Standard Class    RC-19825
# 2589  CA-2016-137729  05/05/2016  05/09/2016  Standard Class    BF-11005
# 7331  CA-2017-115119  10/26/2017  10/30/2017  Standard Class    SC-20440
# 9088  CA-2015-150308  12/15/2015  12/20/2015  Standard Class    RR-19525
#
#      Customer Name      Segment        Country         City           State  \
# 264    Roy Collins     Consumer  United States      Chicago        Illinois
# 2589   Barry Franz  Home Office  United States  Los Angeles      California
# 7331  Shaun Chance    Corporate  United States    Lancaster    Pennsylvania
# 9088     Rick Reed    Corporate  United States         Cary  North Carolina
#
#       Postal Code          Region       Product ID    Category Sub-Category  \
# 264       60610.0        Illinois  TEC-PH-10001433  Technology       Phones
# ...

# %%
 264, 321, 399

# %%
df.loc[[264]]
# Out:
#            Order ID  Order Date  Ship Date       Ship Mode Customer ID  \
# 264  CA-2016-125318  06/06/2016  6/13/2016  Standard Class    RC-19825
#
#     Customer Name   Segment        Country     City     State  Postal Code  \
# 264   Roy Collins  Consumer  United States  Chicago  Illinois      60610.0
#
#        Region       Product ID    Category Sub-Category  \
# 264  Illinois  TEC-PH-10001433  Technology       Phones
#
#                                  Product Name    Sales  Quantity  Discount  \
# 264  Cisco Small Business SPA 502G VoIP phone  328.224       NaN       0.2
#
#       Profit
# 264  28.7196

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688  06/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
 264, 321, 399

# %%
df.isnull().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9989    0
# 9990    0
# 9991    0
# 9992    0
# 9993    0
# Length: 9994, dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#            Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 264  CA-2016-125318  06/06/2016   6/13/2016  Standard Class    RC-19825
# 321  CA-2014-164973  11/04/2014  11/09/2014  Standard Class    NM-18445
# 399  CA-2016-108987  09/08/2016  09/10/2016    Second Class    AG-10675
#
#     Customer Name      Segment        Country           City     State  \
# 264   Roy Collins     Consumer  United States        Chicago  Illinois
# 321  Nathan Mautz  Home Office  United States  New York City  New York
# 399   Anna Gayman     Consumer  United States        Houston     Texas
#
#      Postal Code    Region       Product ID         Category Sub-Category  \
# 264      60610.0  Illinois  TEC-PH-10001433       Technology       Phones
# 321      10024.0  New York  OFF-ST-10002974  Office Supplies      Storage
# 399      77036.0     Texas  FUR-BO-10004834        Furniture    Bookcases
#
#                                           Product Name      Sales  Quantity  \
# ...

# %%
df.dropna(axis=0)
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688  06/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
dup = df[df.duplicated()]

# %%
dup
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3406  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  Postal Code  \
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio      43229.0
#
#      Region       Product ID   Category Sub-Category  \
# 3406   Ohio  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3406  Global Leather Highback Executive Chair with P...  281.372       2.0
#
#       Discount   Profit
# 3406       0.3 -12.0588

# %%
df.loc[[3405]]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3405  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  Postal Code  \
# 3405  Laurel Beltran  Home Office  United States  Columbus  Ohio      43229.0
#
#      Region       Product ID   Category Sub-Category  \
# 3405   Ohio  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3405  Global Leather Highback Executive Chair with P...  281.372       2.0
#
#       Discount   Profit
# 3405       0.3 -12.0588

# %%
df[df.duplicated(keep=False)]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3405  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
# 3406  US-2014-150119  4/23/2014  4/27/2014  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  Postal Code  \
# 3405  Laurel Beltran  Home Office  United States  Columbus  Ohio      43229.0
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio      43229.0
#
#      Region       Product ID   Category Sub-Category  \
# 3405   Ohio  FUR-CH-10002965  Furniture       Chairs
# 3406   Ohio  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3405  Global Leather Highback Executive Chair with P...  281.372       2.0
# 3406  Global Leather Highback Executive Chair with P...  281.372       2.0
#
#       Discount   Profit
# 3405       0.3 -12.0588
# 3406       0.3 -12.0588

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688  06/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df.drop_duplicates()
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688  06/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df['Region'].value_counts()
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688  06/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017  03/03/2017  Standard Class    DB-13060
# 9993  CA-2017-119914  05/04/2017  05/09/2017    Second Class    CC-12220
#
#          Customer Name    Segment        Country             City       State  \
# ...

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df['Region'] = df['Region'].replace({'W': 'West','C': 'Central','E': 'East','S': 'South'})
